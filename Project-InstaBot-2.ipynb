# %%
from selenium import webdriver
import time

# %%
# opening window in automated brower.
driver_path = "chromedriver"
brave_path = "C:/Program Files/BraveSoftware/Brave-Browser/Application/brave.exe"

option = webdriver.ChromeOptions()
option.binary_location = brave_path
# option.add_argument("--incognito") OPTIONAL
# option.add_argument("--headless") OPTIONAL

# Create new Instance of Chrome
driver = webdriver.Chrome(executable_path=driver_path, options=option)
driver.get('https://www.instagram.com/?hl=en')

# %%
# Passing texts and logging into the instagram account
driver.find_element_by_name('username').send_keys('-------')
driver.find_element_by_name('password').send_keys('-------')
login_btn=driver.find_element_by_xpath('//button[@class="sqdOP  L3NKy   y3zKF     "]')
login_btn.click()

time.sleep(3)

# %%
# Taking care of Turn on notifications message.
driver.find_element_by_xpath('//button[@class="aOOlW   HoLwm "]').click()

# %% [markdown]
# Search Top Handles of Food

# %%
# searching for food and printing instagram handles.
search_bar=driver.find_element_by_xpath('//input[@type="text"]')
search_bar.send_keys('food')
time.sleep(3)

Instagram_Handles=[]
li=driver.find_elements_by_xpath('//a[@class="yCE8d  "]/div/div/div[1]/span')
for i in li:
    Instagram_Handles.append(i.get_attribute('innerHTML'))

# %%
for i in Instagram_Handles:
    if i[0]=='#':
        Instagram_Handles.remove(i)
Instagram_Handles=Instagram_Handles[:12]

# %%
Instagram_Handles=Instagram_Handles[1:]
Instagram_Handles
# Out:
# ['foodtalkindia',
#  'buzzfeedfood',
#  'dilsefoodie',
#  'foodinsider',
#  'foodbeast',
#  'food52',
#  'food',
#  'foodandwine',
#  'hmm_nikhil',
#  'foodnetwork']

# %% [markdown]
# Find Total Followers of each Top Handles

# %%
# extracting total followers of each handle and storing in a dictionary.
d_followers={}
for i in Instagram_Handles:
    search_bar=driver.find_element_by_xpath('//input[@type="text"]')
    search_bar.send_keys(i)
    time.sleep(2)
    
    if i=='food':
        time.sleep(2)
        driver.find_element_by_xpath('//a[@href="/food/"]').click()
        time.sleep(2)
        d_followers[i]=driver.find_element_by_xpath('//a[@class="-nal3 "]/span').get_attribute('innerHTML')
        time.sleep(1)
    else:
        time.sleep(2)
        driver.find_element_by_xpath('//div[@class="fuqBx"]/a').click()
        time.sleep(2)
        d_followers[i]=driver.find_element_by_xpath('//a[@class="-nal3 "]/span').get_attribute('innerHTML')
        time.sleep(1)
d_followers
# Out:
# {'foodtalkindia': '293k',
#  'buzzfeedfood': '3.7m',
#  'dilsefoodie': '377k',
#  'foodinsider': '2.1m',
#  'foodbeast': '1.1m',
#  'food52': '2.6m',
#  'food': '13.2k',
#  'foodandwine': '3.3m',
#  'hmm_nikhil': '19.9k',
#  'foodnetwork': '10.1m'}

# %%
# top 5 instagram handles with respect to number of followers
top_handles=['buzzfeedfood','foodinsider','foodbeast','dilsefoodie','foodtalkindia']

# %% [markdown]
# Find Comments of Top Handles

# %%
from bs4 import BeautifulSoup
d={}
for i in top_handles:
    d[i]=list()

# %%
for i in top_handles:
    search_bar=driver.find_element_by_xpath('//input[@type="text"]')
    search_bar.send_keys(i)
    time.sleep(2)
    driver.find_element_by_xpath('//div[@class="fuqBx"]/a').click()
    time.sleep(3)
    links_posts=driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]/a')
    time.sleep(2)
    for j in links_posts[:10]:
        j.click()
        time.sleep(3)
        html=driver.find_element_by_xpath('//div[@class="C4VMK"]/span').get_attribute('innerHTML')
        data=BeautifulSoup(html,'html.parser')
        d[i].append(data.get_text())
        driver.find_element_by_xpath('//div[@class="                   Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG"]').click()
        time.sleep(3)
d
# Out:
# {'buzzfeedfood': ['This place in Seattle serves tide-to-table shellfish! 😱Follow 👉@bringme for more foodie spots around the world!',
#   'Are you ready to get bougie on a budget? You can get a Michelin star meal in Paris! 🇫🇷Follow 👉@bringme for more foodie adventures!',
#   'This place in Seattle serves tide-to-table shellfish! 😱Follow 👉@bringme for more foodie spots around the world!',
#   'Are you ready to get bougie on a budget? You can get a Michelin star meal in Paris! 🇫🇷Follow 👉@bringme for more foodie adventures!',
#   "Why aren't you following @bringme yet?! 🍜Follow @bringme for more foodie adventures! 🌍✈️",
#   'Brazil makes the cheesiest chili cheeseburgers! 😋🍔Follow @bringme for more!',
#   "Move over Italy, Vancouver might have the world's best gelato! 🍨What's your favorite gelato flavor? Follow 👉@bringme for more mouthwatering adventures around the globe! 🌎",
#   'Sushi + sustainability = my dream come true! 🍣Follow @bringme for more foodie adventures around the world! ✈️.....#bringme #portlandtravel #sushirestuarant #sushi #oregontravel #sustainability',
#   "These are cheesecake tea cups and I'll take one of EVERYTHING. 😍🍰Follow @bringme for more foodie adventures! ✈️",
#   'This place serves pickle and beer flights with a southern twist! 🍻Follow @bringme for more foodie adventures all around the globe! ✈️',
#   'Cozy up at this hot chocolate café! They have over 50 different kinds! ☕️🍫Follow @bringme for more foodie adventures around the world! ✈️',
#   'Thanks for this dairy-free blueberry lime “cheesecake” recipe @goodful 😍🤤',
#   'This place in Seattle serves tide-to-table shellfish! 😱Follow 👉@bringme for more foodie spots around the world!',
#   'Are you ready to get bougie on a budget? You can get a Michelin star meal in Paris! 🇫🇷Follow 👉@bringme for more foodie adventures!',
#   "Why aren't you following @bringme yet?! 🍜Follow @bringme for more foodie adventures! 🌍✈️",
#   'Brazil makes the cheesiest chili cheeseburgers! 😋🍔Follow @bringme for more!',
#   "Move over Italy, Vancouver might have the world's best gelato! 🍨What's your favorite gelato flavor? Follow 👉@bringme for more mouthwatering adventures around the globe! 🌎",
#   'Sushi + sustainability = my dream come true! 🍣Follow @bringme for more foodie adventures around the world! ✈️.....#bringme #portlandtravel #sushirestuarant #sushi #oregontravel #sustainability',
#   "These are cheesecake tea cups and I'll take one of EVERYTHING. 😍🍰Follow @bringme for more foodie adventures! ✈️",
#   'This place serves pickle and beer flights with a southern twist! 🍻Follow @bringme for more foodie adventures all around the globe! ✈️',
#   'Cozy up at this hot chocolate café! They have over 50 different kinds! ☕️🍫Follow @bringme for more foodie adventures around the world! ✈️',
#   '12 Los Angeles restaurants to order takeout from while social distancingIn an effort to stop the spread of the novel coronavirus, state governments are declaring mandates to close bars and restaurants except for pickup or delivery orders. Los Angeles is now one of several states with these restrictions, which are already affecting local business. Here is a small but comprehensive list of 12 small business restaurants that you can order pickup or delivery from.Featuring @mooscraftbarbecue, @employeesonlyla, @sonoratownla, @guerillatacos, @riceboxla, @crossroadskitchen, @slab, @primosdonutsla, @tsujitala, @tacos1986la, @thepienburger #fooddelivery #coronavirus #socialdistancing #food #FoodInsider',
#   'This animated map shows where your favorite coffee actually comes from ☕️Nearly two thirds of Americans drink coffee everyday, but how many of them know where it comes from? If you sip your morning joe from major brands like Starbucks, Dunkin’, or McDonalds, chances are it comes from one of several countries in Latin America. Companies source from different regions to reduce risk, maintain a steady supply of beans in different seasons, and serve different flavors to their customers.#coffee #map #coffeemap #food #FoodInsider',
#   "47 drinks to add to your bucket list | The Ultimate ListThis is the ultimate must-try drinks bucket list. From colorful coffees to 100-ounce cocktails, here are 47 eclectic drinks you have to try before you die and where you can get them. Among the favorites are the boba mimosa from Orlando's Domu and a Bloody Mary topped with two fried hens from Party Fowl in Nashville.#drinks #TheUltimateList #food #FoodInsider",
#   'Why lobster is so expensive | So ExpensiveVia @businessinsiderLobster went from prison food to a well-known delicacy. Seafood was left out of rationed foods during WWII, and with the advent of railway transportation, lobster became known as an exotic delicacy.#lobster #expensivelobster #seafood #WWII #prisonfood #FoodInsider',
#   'What the keto diet actually does to your body 🥑The ketogenic diet, or keto, has become a popular way to lose weight. The high-fat, low-carb diet is a drastic change from the diet that the USDA recommends for Americans. It’s also a huge change for your body’s metabolism.#keto #ketogenic #ketogenicdiet #diet #ScienceInsider'],
#  'foodbeast': ['Mr. Booth 👶🏻 pays his 4th visit to L’Dad’s Chateau (@boothums), this evening for a light quesadilla arrangement. Eat well young #foodbeast! Who’s ready for episode 5?!',
#   'DORITOS LOCOS QUESARITO 🌶🔥🌯🧀 one of the dope dishes from our @foodbeastkitchen League matchups on @twitch!!! This creation comes from the mind of @thejoshelkin, who crusted Doritos around a scratch-made quesarito to bring this dish to life! Should @tacobell put this on their menu, #foodbeast fam? Sound off in the comments, and check our Twitch channel for more cooking fun like this! Twitch.tv/foodbeast',
#   'ELOTE GRILLED SHRIMP special order from @tacoslacalle! This dish is made on request, with ELOTE, grilled shrimp, guacamole and nacho cheese. If you’re around #BuenaPark, hit one of the delivery apps and indulge! #foodbeast',
#   'Day 2: Chocolate ChipsOn day 2 of @bookofelie’s journey to master the mysterious 2-Ingredient Banana Pancakes, he learns heat control and pancake flipping. Also, he adds a 3rd ingredient to the mix. What will Day 3 entail?!',
#   '#FoodNews: #Subway has launched something called Subway Grocery. They note it’s a way for customers to get stuff like meats, breads, cheese and produce m, as well as giving back to local communities. #foodbeast @pham_bot has the full story and all details on foodbeast.com, as well as through the link in our bio.',
#   '#FoodNews: New updated #Costco guidelines are making their rounds. Full story and details on #Foodbeast.com and the link in our bio.',
#   '#FoodNews #CPG: HONEYRACHA 🍯🔥🌶?!? Where y’all land on this? #foodbeast @familyfooddude claims “this stuff is 🔥” Found at #WalMart!',
#   'Mr. Booth 👶🏻 pays his 4th visit to L’Dad’s Chateau (@boothums), this evening for a light quesadilla arrangement. Eat well young #foodbeast! Who’s ready for episode 5?!',
#   "Want to help daily wage workers? Here are 6 organisations that are supporting those who are struggling to make ends meet.1. Adi Shakti Shiksha Foundation: Distribution of food in Gurgaon @adishaktishiksha.2. The SAFA Society: Distributing relief packages across — Delhi, Chennai, Hyderabad and Bengaluru. @safaindia3. Ketto: Raising multiple funds to aid daily wage earners, waste pickers, and urban poor. @kettoindia4. Zomato Feed the Daily Wager: Donating ration kits worth Rs 500, containing wheat flour or rice, pulses, soap required for a family for one week. @feedingindia @zomatoin #FeedTheDailyWager.5. Our Democracy: Raising funds for daily wagers who don't have the luxury of working from home. @ourdemocracy.in6. Give India: Providing hygiene kits and food provisions to COVID hit families. @give_india",
#   'Our Founder @shuchirsuri is going live at 5pm today with Amit Arora from the Buddy group and @nrai_youthcommittee. Subject: How to use your restaurant kitchen in this time of crisis to help the needy. Tune in']}

# %% [markdown]
# Find Word Frequencies

# %%
li_words=[]
for i in d.values():
    for j in i:
        j=j.replace('.','')
        j=j.replace('🇫🇷','')
        j=j.replace('?','')
        j=j.replace(',','')
        j=j.replace('+','')
        j=j.replace('=','')
        j=j.replace('"','')
        j=j.replace('!','')
        j=j.replace('-','')
        j=j.replace('@','')
        j=j.replace(':','')
        j=j.replace('🥑','')
        j=j.replace('🍣','')
        j=j.replace('😍🍰','')
        j=j.replace('🍻','')
        j=j.replace('☕️🍫','')
        j=j.replace('✈️','')
        j=j.replace('🍜','')
        j=j.replace('😱','')
        j=j.replace('👉','')
        j=j.replace('😋🍔','')
        j=j.replace('🍨','')
        j=j.replace('🥪','')
        j=j.replace('📸','')
        j=j.replace('🏃\u200d♀️‘','')
        j=j.replace('💻','')
        j=j.replace('👨\u200d👩\u200d👧\u200d👦','')
        for k in j.split():
            li_words.append(k)

# %%
# calculating frequency of each word.
freq_words={}
d_words={}
for i in li_words:
    d_words[i]=d_words.get(i,0)+1
d_words
# Out:
# {'This': 14,
#  'place': 5,
#  'in': 35,
#  'Seattle': 3,
#  'serves': 5,
#  'tidetotable': 3,
#  'shellfish': 3,
#  'Follow': 22,
#  'bringme': 22,
#  'for': 48,
#  'more': 25,
#  'foodie': 16,
#  'spots': 3,
#  'around': 16,
#  'the': 92,
#  'world': 10,
#  'Are': 3,
#  'you': 22,
#  'ready': 5,
#  'to': 87,
#  'get': 11,
#  'bougie': 3,
#  'on': 32,
#  'a': 49,
#  'budget': 3,
#  'You': 7,
#  'can': 17,
#  'Michelin': 3,
#  'star': 3,
#  'meal': 3,
#  'Paris': 3,
#  'adventures': 15,
#  'Why': 6,
#  "aren't": 2,
#  'following': 2,
#  'yet': 3,
#  '🌍': 2,
#  'Brazil': 2,
#  'makes': 2,
#  'cheesiest': 2,
#  'chili': 2,
#  'cheeseburgers': 2,
#  'Move': 2,
#  'over': 4,
#  'Italy': 2,
#  'Vancouver': 2,
#  'might': 2,
#  'have': 11,
#  "world's": 2,
#  'best': 3,
#  'gelato': 4,
#  "What's": 2,
#  'your': 27,
#  'favorite': 6,
#  'flavor': 2,
#  'mouthwatering': 2,
#  'globe': 4,
#  '🌎': 2,
#  'Sushi': 2,
#  'sustainability': 2,
#  'my': 3,
#  'dream': 3,
#  'come': 3,
#  'true': 2,
#  '#bringme': 2,
#  '#portlandtravel': 2,
#  '#sushirestuarant': 2,
#  '#sushi': 2,
#  '#oregontravel': 2,
#  '#sustainability': 2,
#  'These': 4,
#  'are': 28,
#  'cheesecake': 2,
#  'tea': 2,
#  'cups': 2,
#  'and': 69,
#  "I'll": 2,
#  'take': 3,
#  'one': 14,
#  'of': 56,
#  'EVERYTHING': 2,
#  'pickle': 2,
#  'beer': 2,
#  'flights': 2,
#  'with': 25,
#  'southern': 2,
#  'twist': 3,
#  'all': 7,
#  'Cozy': 2,
#  'up': 8,
#  'at': 12,
#  'this': 17,
#  'hot': 3,
#  'chocolate': 2,
#  'café': 2,
#  'They': 4,
#  '50': 2,
#  'different': 8,
#  'kinds': 2,
#  'Thanks': 2,
#  'dairyfree': 2,
#  'blueberry': 2,
#  'lime': 2,
#  '“cheesecake”': 2,
#  'recipe': 3,
#  'goodful': 2,
#  '😍🤤': 2,
#  'The': 13,
#  'electric': 2,
#  'fruit': 4,
#  'peeler': 2,
#  '🍊|': 2,
#  'It’s': 5,
#  'Cool': 2,
#  'But': 2,
#  'Does': 2,
#  'It': 3,
#  'Really': 2,
#  'WorkThe': 2,
#  'Orange': 4,
#  'Peel': 4,
#  'Pro': 4,
#  'peels': 2,
#  'lightning': 2,
#  'speeds': 2,
#  'jacobgabbard': 2,
#  'medhapedia': 2,
#  'put': 5,
#  'it': 13,
#  'test': 2,
#  'see': 2,
#  'if': 2,
#  'really': 2,
#  'peel': 4,
#  'three': 4,
#  'five': 2,
#  'fruits': 5,
#  'just': 2,
#  'minute': 2,
#  'Oranges': 2,
#  'apples': 2,
#  'kiwis': 2,
#  'mangoes': 2,
#  'avocados': 2,
#  'onions': 2,
#  'we': 4,
#  'try': 4,
#  'allYou': 2,
#  'purchase': 2,
#  'herehttps//usaunlimitedllccom/product/orangepeelprofessional/#fruitpeeler': 2,
#  '#fruit': 2,
#  '#gadgets': 2,
#  '#tech': 2,
#  '#FoodInsider': 16,
#  'wagyu': 2,
#  'beef': 6,
#  'is': 25,
#  'so': 7,
#  'expensive': 6,
#  '|': 6,
#  'So': 4,
#  'ExpensiveWagyu': 2,
#  'most': 6,
#  'prized': 2,
#  'A': 3,
#  'single': 2,
#  'cow': 2,
#  'be': 7,
#  'sold': 2,
#  '$30000': 2,
#  'Part': 2,
#  'reason': 2,
#  'why': 2,
#  "it's": 2,
#  'due': 2,
#  'its': 4,
#  'exclusivity': 2,
#  'increasing': 2,
#  'demand#Wagyu': 2,
#  '#wagyubeef': 2,
#  '#beef': 2,
#  '#culinary': 2,
#  '#food': 12,
#  'rise': 2,
#  'fall': 2,
#  'Subway': 4,
#  'With': 10,
#  'thousands': 2,
#  'store': 3,
#  'closures': 2,
#  'last': 3,
#  'years': 2,
#  'petitions': 2,
#  'against': 2,
#  'subway': 2,
#  'from': 37,
#  'franchise': 2,
#  'owners': 2,
#  'fastfood': 2,
#  'chain': 2,
#  'locations': 2,
#  'globally': 2,
#  'seems': 2,
#  'rocks': 2,
#  'We': 3,
#  'unpack': 2,
#  "what's": 2,
#  'going': 3,
#  'where': 8,
#  "Subway's": 2,
#  'headed': 2,
#  'here#Subway': 2,
#  '#sandwich': 2,
#  '#restaurant': 2,
#  '8': 4,
#  'New': 4,
#  'Jersey': 2,
#  'restaurants': 12,
#  'order': 8,
#  'takeout': 6,
#  'while': 6,
#  'social': 7,
#  'distancingIn': 4,
#  'an': 8,
#  'effort': 4,
#  'stop': 5,
#  'spread': 4,
#  'novel': 4,
#  'coronavirus': 4,
#  'state': 4,
#  'governments': 4,
#  'declaring': 4,
#  'mandates': 4,
#  'close': 4,
#  'bars': 4,
#  'except': 4,
#  'pickup': 6,
#  'or': 13,
#  'delivery': 10,
#  'orders': 4,
#  'As': 2,
#  'publication': 2,
#  'these': 4,
#  'were': 2,
#  'offering': 2,
#  'either': 2,
#  'though': 2,
#  'hours': 2,
#  'availability': 2,
#  'subject': 2,
#  'change': 6,
#  'Tony': 2,
#  "Boloney's": 2,
#  'Hoboken': 8,
#  '(201)': 14,
#  '2228669': 2,
#  "tonyboloneyscomO'Bagel": 2,
#  '6838600': 2,
#  "directchownowcomFiore's": 2,
#  'House': 2,
#  'Quality': 2,
#  '6591655': 2,
#  '(pickup': 2,
#  "only)Carlo's": 2,
#  'Bakery': 2,
#  '6593671': 2,
#  'orderscarlosbakerycomBrother': 2,
#  "Bruno's": 2,
#  'Wayne': 2,
#  '(973)': 2,
#  '7903321': 2,
#  'directchownowcomCARS': 2,
#  'Sandwiches': 2,
#  '&': 4,
#  'Shakes': 2,
#  'Ramsey': 2,
#  '8718600': 2,
#  'wwweatatcarscomKimchi': 2,
#  'Smoke': 2,
#  'Westwood': 2,
#  '4976333': 2,
#  'directchownowcom': 2,
#  'Brownstone': 2,
#  'Pancake': 2,
#  'Factory': 2,
#  'Edgewater': 2,
#  '9454800': 2,
#  'ubereatscom#Jersey': 2,
#  '#NewJersey': 2,
#  '#takeout': 2,
#  'Tag': 2,
#  'us': 5,
#  'delicious': 3,
#  'quarantine': 5,
#  'dishes': 4,
#  'chance': 2,
#  'featured': 2,
#  'our': 18,
#  'feed': 2,
#  'few': 2,
#  'tasty': 2,
#  'meals': 2,
#  'food': 9,
#  'producers': 2,
#  'cooked': 2,
#  'distancing': 2,
#  '🥗🥖🥘': 2,
#  'along': 2,
#  'what': 4,
#  'they': 3,
#  'making': 4,
#  'home': 4,
#  'crepesofwrath': 4,
#  'lisaparadise': 4,
#  'rinnny_': 2,
#  '#foodfromhome': 2,
#  '#workingfromhome': 2,
#  '#foodinsider': 2,
#  '#quarantinedishes(Credit': 2,
#  'rinnny_/Instagram)': 2,
#  '12': 4,
#  'Los': 4,
#  'Angeles': 4,
#  'now': 2,
#  'several': 4,
#  'states': 2,
#  'restrictions': 2,
#  'which': 3,
#  'already': 2,
#  'affecting': 2,
#  'local': 6,
#  'business': 4,
#  'Here': 4,
#  'small': 4,
#  'but': 4,
#  'comprehensive': 2,
#  'list': 6,
#  'that': 6,
#  'fromFeaturing': 2,
#  'mooscraftbarbecue': 2,
#  'employeesonlyla': 2,
#  'sonoratownla': 2,
#  'guerillatacos': 2,
#  'riceboxla': 2,
#  'crossroadskitchen': 2,
#  'slab': 2,
#  'primosdonutsla': 2,
#  'tsujitala': 2,
#  'tacos1986la': 2,
#  'thepienburger': 2,
#  '#fooddelivery': 2,
#  '#coronavirus': 2,
#  '#socialdistancing': 2,
#  'animated': 2,
#  'map': 2,
#  'shows': 3,
#  'coffee': 5,
#  'actually': 4,
#  'comes': 8,
#  '☕️Nearly': 2,
#  'two': 4,
#  'thirds': 2,
#  'Americans': 4,
#  'drink': 2,
#  'everyday': 2,
#  'how': 4,
#  'many': 3,
#  'them': 5,
#  'know': 2,
#  'If': 5,
#  'sip': 2,
#  'morning': 2,
#  'joe': 2,
#  'major': 2,
#  'brands': 2,
#  'like': 8,
#  'Starbucks': 2,
#  'Dunkin’': 2,
#  'McDonalds': 2,
#  'chances': 2,
#  'countries': 2,
#  'Latin': 2,
#  'America': 2,
#  'Companies': 2,
#  'source': 2,
#  'regions': 2,
#  'reduce': 2,
#  'risk': 2,
#  'maintain': 2,
#  'steady': 2,
#  'supply': 2,
#  'beans': 2,
#  'seasons': 2,
#  'serve': 2,
#  'flavors': 2,
#  'their': 6,
#  'customers#coffee': 2,
#  '#map': 2,
#  '#coffeemap': 2,
#  '47': 4,
#  'drinks': 6,
#  'add': 3,
#  'bucket': 4,
#  'Ultimate': 2,
#  'ListThis': 2,
#  'ultimate': 2,
#  'musttry': 2,
#  'From': 4,
#  'colorful': 2,
#  'coffees': 2,
#  '100ounce': 2,
#  'cocktails': 2,
#  'here': 3,
#  'eclectic': 2,
#  'before': 2,
#  'die': 2,
#  'Among': 2,
#  'favorites': 2,
#  'boba': 2,
#  'mimosa': 2,
#  "Orlando's": 2,
#  'Domu': 2,
#  'Bloody': 2,
#  'Mary': 2,
#  'topped': 2,
#  'fried': 2,
#  'hens': 2,
#  'Party': 3,
#  'Fowl': 2,
#  'Nashville#drinks': 2,
#  '#TheUltimateList': 2,
#  'lobster': 4,
#  'ExpensiveVia': 2,
#  'businessinsiderLobster': 2,
#  'went': 2,
#  'prison': 2,
#  'wellknown': 2,
#  'delicacy': 2,
#  'Seafood': 2,
#  'was': 2,
#  'left': 2,
#  'out': 4,
#  'rationed': 2,
#  'foods': 2,
#  'during': 4,
#  'WWII': 2,
#  'advent': 2,
#  'railway': 2,
#  'transportation': 2,
#  'became': 2,
#  'known': 2,
#  'as': 13,
#  'exotic': 2,
#  'delicacy#lobster': 2,
#  '#expensivelobster': 2,
#  '#seafood': 2,
#  '#WWII': 2,
#  '#prisonfood': 2,
#  'What': 6,
#  'keto': 4,
#  'diet': 8,
#  'does': 3,
#  'body': 2,
#  'ketogenic': 2,
#  'has': 6,
#  'become': 3,
#  'popular': 2,
#  'way': 4,
#  'lose': 2,
#  'weight': 2,
#  'highfat': 2,
#  'lowcarb': 2,
#  'drastic': 2,
#  'USDA': 2,
#  'recommends': 2,
#  'also': 2,
#  'huge': 2,
#  'body’s': 2,
#  'metabolism#keto': 2,
#  '#ketogenic': 2,
#  '#ketogenicdiet': 2,
#  '#diet': 2,
#  '#ScienceInsider': 2,
#  'Mr': 2,
#  'Booth': 2,
#  '👶🏻': 2,
#  'pays': 2,
#  'his': 4,
#  '4th': 2,
#  'visit': 2,
#  'L’Dad’s': 2,
#  'Chateau': 2,
#  '(boothums)': 2,
#  'evening': 2,
#  'light': 2,
#  'quesadilla': 2,
#  'arrangement': 2,
#  'Eat': 2,
#  'well': 6,
#  'young': 2,
#  '#foodbeast': 11,
#  'Who’s': 2,
#  'episode': 2,
#  '5': 2,
#  'DORITOS': 2,
#  'LOCOS': 2,
#  'QUESARITO': 2,
#  '🌶🔥🌯🧀': 2,
#  'dope': 2,
#  'foodbeastkitchen': 2,
#  'League': 2,
#  'matchups': 2,
#  'twitch': 2,
#  'creation': 2,
#  'mind': 2,
#  'thejoshelkin': 2,
#  'who': 5,
#  'crusted': 2,
#  'Doritos': 2,
#  'scratchmade': 2,
#  'quesarito': 2,
#  'bring': 2,
#  'dish': 4,
#  'life': 3,
#  'Should': 2,
#  'tacobell': 2,
#  'menu': 2,
#  'fam': 4,
#  'Sound': 2,
#  'off': 2,
#  'comments': 2,
#  'check': 2,
#  'Twitch': 2,
#  'channel': 2,
#  'cooking': 3,
#  'fun': 4,
#  'Twitchtv/foodbeast': 2,
#  'ELOTE': 4,
#  'GRILLED': 3,
#  'SHRIMP': 2,
#  'special': 2,
#  'tacoslacalle': 2,
#  'made': 2,
#  'request': 2,
#  'grilled': 2,
#  'shrimp': 2,
#  'guacamole': 2,
#  'nacho': 2,
#  'cheese': 4,
#  'you’re': 2,
#  '#BuenaPark': 2,
#  'hit': 3,
#  'apps': 2,
#  'indulge': 2,
#  'Day': 4,
#  '2': 4,
#  'Chocolate': 2,
#  'ChipsOn': 2,
#  'day': 2,
#  'bookofelie’s': 2,
#  'journey': 2,
#  'master': 2,
#  'mysterious': 2,
#  '2Ingredient': 2,
#  'Banana': 2,
#  'Pancakes': 2,
#  'he': 5,
#  'learns': 2,
#  'heat': 2,
#  'control': 2,
#  'pancake': 2,
#  'flipping': 2,
#  'Also': 2,
#  'adds': 2,
#  '3rd': 2,
#  'ingredient': 2,
#  'mix': 2,
#  'will': 4,
#  '3': 2,
#  'entail': 2,
#  '#FoodNews': 6,
#  '#Subway': 2,
#  'launched': 2,
#  'something': 2,
#  'called': 2,
#  'Grocery': 3,
#  'note': 2,
#  'it’s': 2,
#  'customers': 3,
#  'stuff': 4,
#  'meats': 2,
#  'breads': 2,
#  'produce': 3,
#  'm': 2,
#  'giving': 2,
#  'back': 3,
#  'communities': 2,
#  'pham_bot': 2,
#  'full': 2,
#  'story': 4,
#  'details': 4,
#  'foodbeastcom': 2,
#  'through': 4,
#  'link': 4,
#  'bio': 4,
#  'updated': 2,
#  '#Costco': 2,
#  'guidelines': 2,
#  'rounds': 2,
#  'Full': 2,
#  '#Foodbeastcom': 2,
#  '#CPG': 2,
#  'HONEYRACHA': 2,
#  '🍯🔥🌶': 2,
#  'Where': 2,
#  'y’all': 2,
#  'land': 2,
#  'familyfooddude': 2,
#  'claims': 2,
#  '“this': 2,
#  '🔥”': 2,
#  'Found': 2,
#  '#WalMart': 2,
#  'BREAKFAST': 1,
#  'BURRITO': 1,
#  'cornerburger': 1,
#  'passes': 1,
#  '#Foodbeast': 1,
#  '👁test': 1,
#  '#BurritoBust': 1,
#  'ANIMAL': 1,
#  'STYLE': 1,
#  'FRIES': 1,
#  'RACK': 1,
#  'OF': 1,
#  'INNOUT': 1,
#  'BURGERS': 1,
#  '🍔': 1,
#  '🍟//': 1,
#  'Beautifully': 1,
#  'eaten': 1,
#  'by': 3,
#  'foodieoc': 1,
#  'PEANUT': 1,
#  'BUTTER': 1,
#  'HONEY': 1,
#  'BACON': 1,
#  'SPICY': 1,
#  'SANDWICH': 1,
#  '🥜': 1,
#  '🍯': 1,
#  '🥓': 1,
#  '🌶': 1,
#  'Made': 1,
#  '#foodbeasts': 1,
#  'Greg': 1,
#  'Rebecca': 1,
#  'devourpower': 1,
#  'sandwich': 1,
#  'involves': 1,
#  'crispy': 1,
#  'bacon': 1,
#  'peanut': 1,
#  'butter': 3,
#  'honey': 1,
#  'sauced': 1,
#  'sauce': 1,
#  '❤️👀🔥🤤': 1,
#  'Dahi': 2,
#  'Wale': 4,
#  'Golgappe': 4,
#  '😍': 1,
#  'Bhai': 1,
#  'Mujhe': 1,
#  'To': 3,
#  'Aise': 1,
#  'Pasand': 2,
#  'HaiApko': 1,
#  'Kaise': 1,
#  'Simple': 2,
#  'Paani': 1,
#  'Or': 1,
#  'Bharwa': 1,
#  '#dilsefoodie': 1,
#  '#streetfood': 1,
#  '#lockdown2020': 1,
#  'Punjabi': 1,
#  'Kadhi': 1,
#  'RecipeEasy': 5,
#  'Cooking': 5,
#  'Dilsefoodie': 5,
#  'Episode': 5,
#  '8#dilsefoodie': 1,
#  'Food': 1,
#  'No': 1,
#  'Body': 1,
#  'Can': 2,
#  'Rate': 1,
#  '🙏': 1,
#  'Langar': 1,
#  'At': 2,
#  'Golden': 2,
#  'Temple': 2,
#  'Amritsar': 1,
#  '♥️Tag': 1,
#  'That': 1,
#  'Friend': 1,
#  'Whom': 1,
#  'Wanna': 1,
#  'Go': 1,
#  'After': 2,
#  'Situation': 1,
#  'Get': 2,
#  'Over#dilsefoodie': 1,
#  '#Amritsar': 1,
#  'Most': 1,
#  'Spieciest': 1,
#  'Souji': 1,
#  'Maggi': 1,
#  'Ram': 1,
#  'Khokha': 1,
#  'Returns': 1,
#  'Nagpur#Dilsefoodie': 1,
#  '#nagpur': 1,
#  '#maggi': 1,
#  'Paneer': 2,
#  'Pakode': 1,
#  '7Please': 1,
#  'Coment': 1,
#  'Below': 1,
#  'Like': 1,
#  '#Dilsefoodie': 1,
#  '#easycookingwithdilsefoodie': 4,
#  'Koyle': 1,
#  'Wala': 1,
#  'Bombay': 1,
#  'Sandwich': 1,
#  'In': 2,
#  'Viman': 1,
#  'Nagar': 1,
#  'PuneAnyone': 1,
#  'Pune': 3,
#  'Please': 1,
#  'Tell': 1,
#  'Me': 1,
#  'Not': 1,
#  'Miss': 1,
#  'Lockdown': 1,
#  'Over': 1,
#  'I': 2,
#  'Am': 1,
#  'Planning': 1,
#  'For': 1,
#  'Jammu': 1,
#  'And': 2,
#  'Mumbai#dilsefoodie': 1,
#  '#pune': 1,
#  '#bombaysandwich': 1,
#  'Atte': 1,
#  'Aloo': 1,
#  '6#dilsefoodie': 1,
#  'Capsicum': 1,
#  '5#Dilsefoodie': 1,
#  'Easy': 1,
#  'Way': 1,
#  'Make': 2,
#  'Bhindi': 1,
#  'MasalaCooking': 1,
#  'Dilsefoodie#Dilsefoodie': 1,
#  '#Cookingwithdilsefoodie': 1,
#  'Laccha': 1,
#  'Parantha': 1,
#  '4#Dilsefoodie': 1,
#  '#QuarantineAndChill': 2,
#  '#QarantineGroceryListRide': 1,
#  'recommendations': 1,
#  'next': 2,
#  'trip': 1,
#  '(other': 1,
#  'than': 1,
#  'favourite': 3,
#  'snacks)🍅Veggies': 1,
#  'Fruits': 1,
#  'Fresh': 1,
#  'much': 2,
#  'longer🍖Protein': 1,
#  'freeze': 1,
#  'pretty': 1,
#  'any': 1,
#  'meat': 1,
#  'chicken': 2,
#  'fish🥚Staples': 1,
#  'Do': 1,
#  'quick': 1,
#  'inventory': 1,
#  'milk': 1,
#  'eggs': 1,
#  'oils': 1,
#  'spices': 1,
#  'bread': 1,
#  'rice': 2,
#  'cereal🥫Misc': 1,
#  'Pasta': 1,
#  'quinoa': 1,
#  'canned': 1,
#  'dry': 1,
#  'pulses': 2,
#  'flour': 2,
#  'tortilla': 1,
#  'longer': 1,
#  'shelf': 1,
#  'rescue': 1,
#  'when': 1,
#  'running': 1,
#  'low': 1,
#  'veggies❄️': 1,
#  'Freezer': 1,
#  'pizza': 1,
#  'base': 1,
#  'veggies': 1,
#  'such': 1,
#  'spinach': 1,
#  'broccoli': 1,
#  'carrots': 1,
#  'cauliflower': 1,
#  'frozen': 1,
#  'rainy': 1,
#  'dayJust': 1,
#  'remember': 1,
#  'consider': 1,
#  'need': 1,
#  'others': 1,
#  'don’t': 1,
#  'buy': 1,
#  'stock': 1,
#  'grocery': 1,
#  'storeTip': 1,
#  'Take': 1,
#  'screenshot': 1,
#  'FT': 1,
#  'Quarantine': 1,
#  'List': 1,
#  'shared': 1,
#  'stories': 1,
#  'Join': 1,
#  'shuchirsuri': 2,
#  'sahilmarwaha': 1,
#  'whip': 1,
#  'super': 1,
#  'healthy': 1,
#  'smoothie': 2,
#  'bowl': 2,
#  'live': 3,
#  '4PM': 1,
#  'today': 2,
#  'do': 2,
#  '#Quarantipples': 1,
#  '#WhippedCoffeeGinDon’t': 1,
#  'worry': 1,
#  'aren’t': 1,
#  'bore': 1,
#  'another': 2,
#  '#Dalgona': 1,
#  'tutorialanandinaglass': 1,
#  'greaterthangin': 2,
#  'easy': 1,
#  'cocktail': 2,
#  'tutorial': 2,
#  'time': 4,
#  'using': 1,
#  'whipped': 1,
#  'baseNow': 1,
#  'accepting': 1,
#  'requests': 1,
#  'feature': 1,
#  'Send': 1,
#  'suggestions': 1,
#  'may': 1,
#  'nextCredits': 1,
#  '#TalkRecipe': 1,
#  '#EasyButterChickenMissing': 1,
#  'Pandara’s': 1,
#  'Trust': 1,
#  'no': 1,
#  'fuss': 1,
#  'finger': 1,
#  "lickin'": 1,
#  'goodMake': 1,
#  'learning': 3,
#  'cook': 2,
#  'dishTag': 1,
#  'half': 1,
#  'ask': 1,
#  'pinterest': 1,
#  'Joy': 1,
#  'simplyrecipes': 1,
#  'tablefortwoxyz': 1,
#  'sons': 1,
#  'Tshirt': 1,
#  'him': 1,
#  'chewing': 1,
#  '🙈': 1,
#  '#TalkStreaming': 1,
#  '#RatatouilleA': 1,
#  'comic': 1,
#  'rat': 2,
#  'chef': 1,
#  'almost': 1,
#  'unbearable': 1,
#  'sensuality': 1,
#  'revisit': 1,
#  'feelgood': 1,
#  'movie': 1,
#  'Ratatouille': 1,
#  'Remy': 2,
#  'very': 1,
#  'unusual': 1,
#  'somehow': 1,
#  'lifetime': 1,
#  'sorting': 1,
#  'human': 1,
#  'garbage': 1,
#  'furry': 1,
#  'tribe': 1,
#  'develops': 1,
#  'taste': 2,
#  'fresh': 1,
#  'fate': 1,
#  'winds': 1,
#  'kitchen': 2,
#  'topflight': 1,
#  'Parisian': 1,
#  'restaurant': 2,
#  'Tantalizing': 1,
#  'buds': 1,
#  'even': 1,
#  'jaded': 1,
#  'pursues': 1,
#  'despite': 1,
#  'threat': 1,
#  'being': 1,
#  'ratted': 1,
#  'outRatatouille': 1,
#  'sure': 1,
#  'feels': 1,
#  'those': 2,
#  'classic': 1,
#  'old': 1,
#  'cartoons': 1,
#  'used': 1,
#  'watch': 1,
#  'marathons': 1,
#  'early': 1,
#  'mornings': 1,
#  '🎥': 1,
#  'netflix_in': 1,
#  'wikipedia': 1,
#  '🤣🤣🤣': 1,
#  '#NoQuarantineBluesBeat’': 1,
#  'em': 1,
#  'blues': 1,
#  'tips': 2,
#  'stay': 2,
#  'entertained': 1,
#  'connected': 1,
#  'friends🖥': 1,
#  'Netflix': 2,
#  'Play': 1,
#  'pause': 1,
#  'sync': 1,
#  'friends': 1,
#  'Family': 1,
#  'Cook': 1,
#  'Off': 1,
#  'Divide': 1,
#  'into': 1,
#  'teams': 1,
#  'compete': 1,
#  'title': 1,
#  'chefWork': 1,
#  'in’': 2,
#  'Pick': 1,
#  'exercise': 1,
#  'buddy': 1,
#  'catch': 1,
#  '‘work': 1,
#  'sessions': 1,
#  'happening': 1,
#  'you🎲': 1,
#  'Video': 1,
#  'Calls': 1,
#  'Group': 1,
#  'video': 1,
#  'calls': 1,
#  'games': 1,
#  'Heads': 1,
#  'Up': 1,
#  'Quick': 1,
#  'Draw': 1,
#  'Trivia': 1,
#  ...}

# %%
import pandas as pd
words=list(d_words.keys())
freq=list(d_words.values())
data={'Words':words, 'Frequency':freq}
df=pd.DataFrame(data)
df.to_csv('Frequency.csv',index=False)

# %% [markdown]
# Get Most Used Hashtags

# %%
# creating a dictionary to get top hashtags with respect to number of times it is used.
d={}
for i in d_words.keys():
    if '#' in i:
        d[i]=d_words[i]

from collections import Counter
k=Counter(d)
li=k.most_common(5)
for i in li:
    print(i[0],i[1])
# Out:
# #FoodInsider 16
# #food 12
# #foodbeast 11
# #FoodNews 6
# #easycookingwithdilsefoodie 4

# %% [markdown]
# Hastags use percentage

# %%
# plotting pie for hastags with percentage times used in scraped posts.
import matplotlib.pyplot as plt
times=[]
tags=[]
for i in li:
    tags.append(i[0])
    times.append(i[1])
plt.pie(times,labels=tags,autopct='%.2f%%')
plt.show()

# %% [markdown]
# Find total likes of top recent 10 posts of top handles.

# %%
# dictionary for storing likes of top 10 posts of each handles obtaines earlier.
d_likes={}
for i in top_handles:
    d_likes[i]=list()

# %%
from selenium.common.exceptions import NoSuchElementException
for i in top_handles:
    search_bar=driver.find_element_by_xpath('//input[@type="text"]')
    search_bar.send_keys(i)
    time.sleep(5)
    driver.find_element_by_xpath('//div[@class="fuqBx"]/a').click()
    time.sleep(3)
    links_posts=driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]/a')
    for j in links_posts[:10]:
        j.click()
        time.sleep(3)
        try:
            likes=driver.find_element_by_xpath('//div[@class="Nm9Fw"]/button/span').get_attribute('innerHTML')
            d_likes[i].append(likes.replace(',',''))
        except NoSuchElementException:
            driver.find_element_by_xpath('//div[@class="HbPOm _9Ytll"]/span/span').click()
            time.sleep(2)
            likes=driver.find_element_by_xpath('//div[@class="vJRqr"]/span').get_attribute('innerHTML')
            d_likes[i].append(likes.replace(',',''))
            driver.find_element_by_xpath('//div[@class="QhbhU"]').click()
            time.sleep(1)
        driver.find_element_by_xpath('//div[@class="                   Igw0E     IwRSH      eGOV_         _4EzTm                                                                                  BI4qX            qJPeX            fm1AK   TxciK yiMZG"]').click()
        time.sleep(2)

# %%
# Calculating average likes for a handle.
d_likes_new={}
for i in d_likes.keys():
    total=0
    for j in d_likes[i]:
        total+=float(j)
    d_likes_new[i]=total//10
d_likes_new
# Out:
# {'buzzfeedfood': 5113.0,
#  'foodinsider': 15480.0,
#  'foodbeast': 7801.0,
#  'dilsefoodie': 8836.0,
#  'foodtalkindia': 1403.0}

# %%
# followers:like ratio of each handle.
ratio=[]
for i in d_likes_new.keys():
    d_followers[i]=d_followers[i].replace('k','000')
    d_followers[i]=d_followers[i].replace('.','')
    d_followers[i]=d_followers[i].replace('m','00000')
    ratio.append(int(d_followers[i])/d_likes_new[i])
    print(i,'-->',int(d_followers[i])/d_likes_new[i])
# Out:
# buzzfeedfood --> 723.645609231371
# foodinsider --> 135.65891472868216
# foodbeast --> 141.00756313293166
# dilsefoodie --> 42.66636487098234
# foodtalkindia --> 208.83820384889523

# %%
# plotting data.
plt.bar(top_handles,ratio)
plt.xticks(rotation=25)
plt.title('Average Followers : Likes Ratio')
plt.show()
